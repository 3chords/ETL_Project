# %%
import pandas as pd
import numpy as np

# %%
file1 = "cre_stats_data.csv"
file2 = 'labor_data.csv'
file3 = 'Resources/city_msa.csv'
file4 = 'Resources/StatesFIPSCodes.csv'

# %%
labor_data = pd.read_csv(file2)
labor_data.head()
# Out:
#      MSA                                     MSA Name      2001 Jobs  \
# 0  35620        New York-Newark-Jersey City, NY-NJ-PA  341351.923981
# 1  31080           Los Angeles-Long Beach-Anaheim, CA  308832.247945
# 2  16980           Chicago-Naperville-Elgin, IL-IN-WI  257587.748539
# 3  19100              Dallas-Fort Worth-Arlington, TX  142986.323034
# 4  37980  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD  121049.071284
#
#        2002 Jobs      2003 Jobs      2004 Jobs      2005 Jobs      2006 Jobs  \
# 0  331989.441630  328235.533477  327854.161053  329210.188139  330215.030588
# 1  302561.185043  295121.609903  296917.665708  303190.252877  308991.792593
# 2  247920.850153  244149.724359  246288.482485  250022.755191  254970.189488
# 3  136961.350132  132569.110466  135288.003375  139858.373893  144705.079063
# 4  117839.928018  118305.948225  119012.113767  119791.365177  121129.814163
#
#        2007 Jobs      2008 Jobs  ...  2028 Location Quotient  \
# ...

# %%
cre_stats = pd.read_csv(file1)
cre_stats.head()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (37,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Property Class Name   Period Slice    As Of Geography Name Property Type  \
# 0          Industrial  1981 Q4   All  2019 Q3   Abilene - TX           IND
# 1          Industrial  1982 Q1   All  2019 Q3   Abilene - TX           IND
# 2          Industrial  1982 Q2   All  2019 Q3   Abilene - TX           IND
# 3          Industrial  1982 Q3   All  2019 Q3   Abilene - TX           IND
# 4          Industrial  1982 Q4   All  2019 Q3   Abilene - TX           IND
#
#   Geography Code          Forecast Scenario  CBSA Code Geography Type  ...  \
# 0         G41554  Oxford Economics Baseline    10180.0          Metro  ...
# 1         G41554  Oxford Economics Baseline    10180.0          Metro  ...
# ...

# %%
msa_city = pd.read_csv(file3)
msa_city.head()
# Out:
#   CBSA Code    CBSA Title Metropolitan/Micropolitan Statistical Area  \
# 0     10100  Aberdeen, SD              Micropolitan Statistical Area
# 1     10140  Aberdeen, WA              Micropolitan Statistical Area
# 2     10180   Abilene, TX              Metropolitan Statistical Area
# 3     10220       Ada, OK              Micropolitan Statistical Area
# 4     10300    Adrian, MI              Micropolitan Statistical Area
#
#   Principal City Name  FIPS State Code  FIPS Place Code
# 0            Aberdeen             46.0            100.0
# 1            Aberdeen             53.0            100.0
# 2             Abilene             48.0           1000.0
# 3                 Ada             40.0            200.0
# 4              Adrian             26.0            440.0

# %%
msa_code = msa_city['CBSA Code'].to_list()
msa_name = msa_city['CBSA Title'].to_list()
m_city = msa_city['Principal City Name'].to_list()
m_state_code = msa_city['FIPS State Code'].to_list()

# %%
m_state_code_int= []
for i in m_state_code:
    try:
        m_state_code_int.append(int(i))
    except ValueError:
        m_state_code_int.append(i)
                                
m_state_code_int[0]
# Out:
# 46

# %%
state_FIP_code = pd.read_csv(file4)
state_FIP_code.head()
# Out:
#    STATE_FIPS STUSAB  STATE_NAME  STATENS
# 0           1     AL     Alabama  1779775
# 1           2     AK      Alaska  1785533
# 2           4     AZ     Arizona  1779777
# 3           5     AR    Arkansas    68085
# 4           6     CA  California  1779778

# %%
state_abbre = state_FIP_code['STUSAB'].to_list()
state_fip = state_FIP_code['STATE_FIPS'].to_list()

# %%
state_fip[41] == m_state_code_int[0]
# Out:
# True

# %%
city_state = cre_stats['Geography Name'].to_list()
city_state[0].split(" ")[2]
# Out:
# 'TX'

# %%
city_list= []
state_list = []
for i in city_state:
    city_list.append(i.split(" ")[0])
    state_list.append(i.split(" ")[2])

# %%
cl = len(city_list)
cl
# Out:
# 64903

# %%
a = [[]]*cl

for i in np.arange(cl):
    for j in np.arange(ml):
        if city_list[i] in MSA_city_list[j] and state_list[i] in MSA_state_list[j]:
            a[i] = MSA_name[j]

# %%
new_cres_stats = cre_stats[["MSA Name", 'Property Class Name', 'Period', 'Slice', 'As Of', 'Geography Name',
                           'Property Type', 'Geography Code','Forecast Scenario', 'CBSA Code','Geography Type',
                           'Stock', 'Vacancy','Occupancy','Asking Rent','Asking Rent Index',
                           'Rent Growth','Rent Growth 12 Month','Demand','Net Absorption','Net Absorption 12 Months',
                           'Net Completions 12 Months','Cap Rate','Total Return',
 'Appreciation Return',
 'Income Return',
 'NOI Index',
 'Capital Value Index',
 'Price Index',
 'Price Growth',
 'Market Capitalization',
 'Office Employment',
 'Population',
 'Median Household Income',
 'Total Employment ',
 'Households',
 'Industrial Employment',
 'Transaction Cap Rate',
 '# Transaction Cap Rate',
 'Transaction PricePerArea',
 'Total Sales Volume',
 '# Sales Volume',
 'Sold Building SF',]]

# %%
new_cres_stats.head()
# Out:
#       MSA Name Property Class Name   Period Slice    As Of Geography Name  \
# 0  Abilene, TX          Industrial  1981 Q4   All  2019 Q3   Abilene - TX
# 1  Abilene, TX          Industrial  1982 Q1   All  2019 Q3   Abilene - TX
# 2  Abilene, TX          Industrial  1982 Q2   All  2019 Q3   Abilene - TX
# 3  Abilene, TX          Industrial  1982 Q3   All  2019 Q3   Abilene - TX
# 4  Abilene, TX          Industrial  1982 Q4   All  2019 Q3   Abilene - TX
#
#   Property Type Geography Code          Forecast Scenario  CBSA Code  ...  \
# 0           IND         G41554  Oxford Economics Baseline    10180.0  ...
# 1           IND         G41554  Oxford Economics Baseline    10180.0  ...
# 2           IND         G41554  Oxford Economics Baseline    10180.0  ...
# 3           IND         G41554  Oxford Economics Baseline    10180.0  ...
# 4           IND         G41554  Oxford Economics Baseline    10180.0  ...
#
# ...

# %%
new_cres_stats.to_csv('new_cre_stats_data.csv')
