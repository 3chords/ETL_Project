# %%
import pandas as pd
import numpy as np

# %%
file1 = "cre_stats_data.csv"
file2 = 'labor_data.csv'

# %%
labor_data = pd.read_csv(file2)
labor_data.head()
# Out:
#      MSA                                     MSA Name      2001 Jobs  \
# 0  35620        New York-Newark-Jersey City, NY-NJ-PA  341351.923981
# 1  31080           Los Angeles-Long Beach-Anaheim, CA  308832.247945
# 2  16980           Chicago-Naperville-Elgin, IL-IN-WI  257587.748539
# 3  19100              Dallas-Fort Worth-Arlington, TX  142986.323034
# 4  37980  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD  121049.071284
#
#        2002 Jobs      2003 Jobs      2004 Jobs      2005 Jobs      2006 Jobs  \
# 0  331989.441630  328235.533477  327854.161053  329210.188139  330215.030588
# 1  302561.185043  295121.609903  296917.665708  303190.252877  308991.792593
# 2  247920.850153  244149.724359  246288.482485  250022.755191  254970.189488
# 3  136961.350132  132569.110466  135288.003375  139858.373893  144705.079063
# 4  117839.928018  118305.948225  119012.113767  119791.365177  121129.814163
#
#        2007 Jobs      2008 Jobs  ...  2028 Location Quotient  \
# 0  335000.980810  331294.867665  ...                0.898985
# 1  305598.619837  296033.603838  ...                1.120333
# 2  257803.911532  253471.031632  ...                1.422678
# 3  147249.136147  148162.286036  ...                1.180633
# 4  121416.049783  120652.504806  ...                1.007304
#
#    2029 Location Quotient  Age 45-54 % of Region  Age 14-18 % of Region  \
# 0                0.897536               0.198594               0.020354
# 1                1.117481               0.198321               0.014933
# 2                1.423138               0.188951               0.029103
# 3                1.180581               0.190785               0.026388
# 4                1.005578               0.191427               0.026768
#
#    Age 19-21 % of Region  Age 22-24 % of Region  Age 25-34 % of Region  \
# 0               0.067333               0.085291               0.245226
# 1               0.068881               0.085499               0.250735
# 2               0.078967               0.085330               0.235536
# 3               0.081579               0.087528               0.244737
# 4               0.077599               0.089332               0.240355
#
#    Age 35-44 % of Region  Age 55-64 % of Region  Age 65+ % of Region
# 0               0.187936               0.148148             0.047121
# 1               0.200111               0.136229             0.045288
# 2               0.189520               0.144756             0.047842
# 3               0.199421               0.129211             0.040356
# 4               0.174473               0.154082             0.045964
#
# [5 rows x 86 columns]

# %%
cre_stats = pd.read_csv(file1)
cre_stats.head()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (37,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Property Class Name   Period Slice    As Of Geography Name Property Type  \
# 0          Industrial  1981 Q4   All  2019 Q3   Abilene - TX           IND
# 1          Industrial  1982 Q1   All  2019 Q3   Abilene - TX           IND
# 2          Industrial  1982 Q2   All  2019 Q3   Abilene - TX           IND
# 3          Industrial  1982 Q3   All  2019 Q3   Abilene - TX           IND
# 4          Industrial  1982 Q4   All  2019 Q3   Abilene - TX           IND
#
#   Geography Code          Forecast Scenario  CBSA Code Geography Type  ...  \
# 0         G41554  Oxford Economics Baseline    10180.0          Metro  ...
# 1         G41554  Oxford Economics Baseline    10180.0          Metro  ...
# 2         G41554  Oxford Economics Baseline    10180.0          Metro  ...
# 3         G41554  Oxford Economics Baseline    10180.0          Metro  ...
# 4         G41554  Oxford Economics Baseline    10180.0          Metro  ...
#
#   Median Household Income Total Employment  Households Industrial Employment  \
# 0                     NaN               NaN        NaN                   NaN
# 1                     NaN               NaN     50,890                   NaN
# 2                     NaN               NaN     51,427                   NaN
# 3                     NaN               NaN     51,962                   NaN
# 4                     NaN               NaN     52,271                   NaN
#
#    Transaction Cap Rate # Transaction Cap Rate Transaction PricePerArea  \
# 0                   NaN                    NaN                      NaN
# 1                   NaN                    NaN                      NaN
# 2                   NaN                    NaN                      NaN
# 3                   NaN                    NaN                      NaN
# 4                   NaN                    NaN                      NaN
#
#   Total Sales Volume # Sales Volume Sold Building SF
# 0                NaN            NaN              NaN
# 1                NaN            NaN              NaN
# 2                NaN            NaN              NaN
# 3                NaN            NaN              NaN
# 4                NaN            NaN              NaN
#
# [5 rows x 42 columns]

# %%
city_state = cre_stats['Geography Name'].to_list()
city_state[1827].split("-")[0]
# Out:
# 'Ann Arbor '

# %%
city_state[1]
# Out:
# 'Abilene - TX'

# %%
import re
city_list= []

for i in city_state:
    k = re.split(" - ", i)[0].split('-')[0]
    city_list.append(k)

# %%
state_list = []
for i in city_state:
    k = i.split(' ')[-1]
    state_list.append(k)

# %%
city_list[1827]
# Out:
# 'Ann Arbor'

# %%
print(len(city_list), len(state_list))
# Out:
# 64903 64903

# %%
city_list[26057]
# Out:
# 'Honolulu'

# %%
state_list[26057]
# Out:
# 'HI'

# %%
MSA_name = labor_data['MSA Name']
MSA = labor_data['MSA']
MSA_city =[]
MSA_state = []
for i in MSA_name:
    MSA_city.append(i.split(",")[0])
    MSA_state.append(i.split(",")[1])

# %%
MSA_city_list = []
for i in MSA_city:
    MSA_city_list.append(i.split("-"))

# %%
MSA_name[0]
# Out:
# 'New York-Newark-Jersey City, NY-NJ-PA'

# %%
MSA_state_list =[]


for i in MSA_state:
    MSA_state_list.append(i.split(' ')[1].split('-'))

MSA_state_list
# Out:
# [['NY', 'NJ', 'PA'],
#  ['CA'],
#  ['IL', 'IN', 'WI'],
#  ['TX'],
#  ['PA', 'NJ', 'DE', 'MD'],
#  ['GA'],
#  ['FL'],
#  ['MA', 'NH'],
#  ['TX'],
#  ['MI'],
#  ['CA'],
#  ['DC', 'VA', 'MD', 'WV'],
#  ['WA'],
#  ['MN', 'WI'],
#  ['AZ'],
#  ['CA'],
#  ['OH'],
#  ['CA'],
#  ['OH', 'KY', 'IN'],
#  ['FL'],
#  ['IN'],
#  ['MO', 'IL'],
#  ['TN', 'MS', 'AR'],
#  ['OH'],
#  ['MD'],
#  ['NC', 'SC'],
#  ['CO'],
#  ['PA'],
#  ['CA'],
#  ['TN'],
#  ['MO', 'KS'],
#  ['OR', 'WA'],
#  ['WI'],
#  ['CA'],
#  ['KY', 'IN'],
#  ['FL'],
#  ['RI', 'MA'],
#  ['TX'],
#  ['NV'],
#  ['VA', 'NC'],
#  ['MI'],
#  ['VA'],
#  ['LA'],
#  ['FL'],
#  ['CT'],
#  ['UT'],
#  ['OH'],
#  ['OK'],
#  ['NC'],
#  ['NY'],
#  ['TX'],
#  ['AL'],
#  ['OH'],
#  ['NE', 'IA'],
#  ['NY'],
#  ['SC'],
#  ['NC'],
#  ['CT'],
#  ['MA', 'CT'],
#  ['PA', 'NJ'],
#  ['PA'],
#  ['OH'],
#  ['TN'],
#  ['WI'],
#  ['CT'],
#  ['LA'],
#  ['OK'],
#  ['AR'],
#  ['CA'],
#  ['NC'],
#  ['PA'],
#  ['HI'],
#  ['NY'],
#  ['SC'],
#  ['CA'],
#  ['PA'],
#  ['FL'],
#  ['MA'],
#  ['TX'],
#  ['NY'],
#  ['KY'],
#  ['IA'],
#  ['NM'],
#  ['PA'],
#  ['OH', 'PA'],
#  ['CA'],
#  ['TN', 'GA'],
#  ['AZ'],
#  ['KS'],
#  ['MI'],
#  ['NC'],
#  ['SC'],
#  ['IL'],
#  ['NV'],
#  ['IN'],
#  ['NC'],
#  ['FL'],
#  ['CA'],
#  ['ME'],
#  ['NY'],
#  ['UT'],
#  ['PA'],
#  ['MS'],
#  ['IA', 'IL'],
#  ['GA', 'SC'],
#  ['ID'],
#  ['CA'],
#  ['OH'],
#  ['CO'],
#  ['IN', 'KY'],
#  ['NH'],
#  ['LA'],
#  ['CA'],
#  ['AR'],
#  ['WA'],
#  ['TX'],
#  ['NJ'],
#  ['SC'],
#  ['IL'],
#  ['AL'],
#  ['VA'],
#  ['AL'],
#  ['NC'],
#  ['MO'],
#  ['AL'],
#  ['FL'],
#  ['CA'],
#  ['MI'],
#  ['GA'],
#  ['CA'],
#  ['LA'],
#  ['WI'],
#  ['CA'],
#  ['CA'],
#  ['IN', 'MI'],
#  ['IN'],
#  ['FL'],
#  ['MI'],
#  ['CO'],
#  ['UT'],
#  ['GA', 'AL'],
#  ['NC'],
#  ['FL'],
#  ['TN', 'VA'],
#  ['WV', 'KY', 'OH'],
#  ['PA'],
#  ['AK'],
#  ['GA'],
#  ['TX'],
#  ['MI'],
#  ['FL'],
#  ['MD', 'DE'],
#  ['WI'],
#  ['FL'],
#  ['MS'],
#  ['MN'],
#  ['OR'],
#  ['NE'],
#  ['NY'],
#  ['TX'],
#  ['WA'],
#  ['TX'],
#  ['OR'],
#  ['TX'],
#  ['TX'],
#  ['TX'],
#  ['LA'],
#  ['IL'],
#  ['WV'],
#  ['IA'],
#  ['AR', 'OK'],
#  ['MD', 'WV'],
#  ['NJ'],
#  ['WI'],
#  ['WI'],
#  ['MS'],
#  ['VA'],
#  ['NY'],
#  ['SD'],
#  ['FL'],
#  ['WI'],
#  ['ND', 'MN'],
#  ['GA'],
#  ['CO'],
#  ['CA'],
#  ['IL'],
#  ['GA'],
#  ['NC'],
#  ['LA'],
#  ['SC', 'NC'],
#  ['CT'],
#  ['TX'],
#  ['GA'],
#  ['VT'],
#  ['WI'],
#  ['KS'],
#  ['IL'],
#  ['FL'],
#  ['NC'],
#  ['IN'],
#  ['TN'],
#  ['TX'],
#  ['NC'],
#  ['SC'],
#  ['OH'],
#  ['MN', 'WI'],
#  ['IA', 'NE', 'SD'],
#  ['TN', 'KY'],
#  ['IA'],
#  ['FL'],
#  ['TX'],
#  ['CA'],
#  ['OR'],
#  ['WA'],
#  ['FL'],
#  ['LA'],
#  ['MI'],
#  ['TX'],
#  ['KY'],
#  ['MO'],
#  ['FL'],
#  ['NH', 'VT'],
#  ['WI'],
#  ['MN'],
#  ['CA'],
#  ['MA'],
#  ['AL'],
#  ['NJ'],
#  ['IN'],
#  ['WI'],
#  ['WA'],
#  ['WI', 'MN'],
#  ['AL'],
#  ['IL'],
#  ['TN'],
#  ['VA', 'WV'],
#  ['MI'],
#  ['IN'],
#  ['GA'],
#  ['PA'],
#  ['MI'],
#  ['OH'],
#  ['TN'],
#  ['WA'],
#  ['CT'],
#  ['IL'],
#  ['MO'],
#  ['GA', 'AL'],
#  ['OH'],
#  ['TX'],
#  ['TX', 'AR'],
#  ['PA'],
#  ['CA'],
#  ['OH'],
#  ['MT'],
#  ['PA'],
#  ['GA'],
#  ['OH'],
#  ['MS'],
#  ['AL'],
#  ['CA'],
#  ['VA'],
#  ['TN'],
#  ['WA'],
#  ['WA'],
#  ['MI'],
#  ['VA'],
#  ['VA'],
#  ['MO', 'KS'],
#  ['NH'],
#  ['CA'],
#  ['WV', 'OH'],
#  ['IA'],
#  ['IN'],
#  ['OH'],
#  ['NY'],
#  ['IN'],
#  ['ME'],
#  ['PA'],
#  ['PA'],
#  ['CO'],
#  ['MA'],
#  ['MN'],
#  ['TX'],
#  ['NC'],
#  ['VA'],
#  ['WI'],
#  ['NC'],
#  ['SC'],
#  ['PA'],
#  ['FL'],
#  ['IN'],
#  ['KY'],
#  ['AZ'],
#  ['SC'],
#  ['MO'],
#  ['ND'],
#  ['CA'],
#  ['VA'],
#  ['CO'],
#  ['MS'],
#  ['KY', 'IL'],
#  ['AL'],
#  ['DE'],
#  ['MI'],
#  ['PA'],
#  ['MI'],
#  ['OH'],
#  ['NC'],
#  ['LA'],
#  ['HI'],
#  ['MI'],
#  ['VA'],
#  ['IL'],
#  ['ME'],
#  ['NC'],
#  ['GA'],
#  ['MI'],
#  ['NC'],
#  ['ME'],
#  ['AL'],
#  ['ND', 'MN'],
#  ['NY'],
#  ['NY'],
#  ['GA'],
#  ['NC'],
#  ['WA'],
#  ['CA'],
#  ['AZ'],
#  ['TN'],
#  ['NY'],
#  ['OR'],
#  ['KS'],
#  ['PA'],
#  ['IL'],
#  ['IN'],
#  ['KY'],
#  ['WI'],
#  ['KY'],
#  ['IN'],
#  ['HI'],
#  ['TX'],
#  ['TX'],
#  ['IA'],
#  ['NM'],
#  ['AR'],
#  ['WI'],
#  ['TX'],
#  ['WI'],
#  ['NC'],
#  ['CA'],
#  ['PA'],
#  ['AL'],
#  ['ID'],
#  ['AR'],
#  ['ID'],
#  ['WV'],
#  ['SC'],
#  ['IA'],
#  ['SD'],
#  ['FL'],
#  ['OH'],
#  ['MO', 'IL'],
#  ['WV', 'OH'],
#  ['TN'],
#  ['AL'],
#  ['NC'],
#  ['IN'],
#  ['OH'],
#  ['CO'],
#  ['AL'],
#  ['WA'],
#  ['OR'],
#  ['PA'],
#  ['AR'],
#  ['IL'],
#  ['IL'],
#  ['FL'],
#  ['OR'],
#  ['AZ'],
#  ['NY'],
#  ['OH'],
#  ['WA'],
#  ['TN'],
#  ['WI'],
#  ['GA'],
#  ['WV', 'VA'],
#  ['KS'],
#  ['LA'],
#  ['UT'],
#  ['MT'],
#  ['ID'],
#  ['CA'],
#  ['AL'],
#  ['NC'],
#  ['IN'],
#  ['UT', 'ID'],
#  ['TX'],
#  ['AZ'],
#  ['NY'],
#  ['WI'],
#  ['OH'],
#  ['MI'],
#  ['MD', 'WV'],
#  ['OH'],
#  ['OH'],
#  ['CA'],
#  ['GA'],
#  ['OH'],
#  ['NM'],
#  ['NC'],
#  ['OK'],
#  ['WI'],
#  ['PA'],
#  ['NE'],
#  ['AL'],
#  ['GA'],
#  ['PA'],
#  ['MI'],
#  ['MS'],
#  ['IL', 'MO'],
#  ['TX'],
#  ['OR'],
#  ['NY'],
#  ['TX'],
#  ['NJ'],
#  ['NH'],
#  ['WV'],
#  ['TX'],
#  ['AR'],
#  ['CA'],
#  ['SC'],
#  ['KY'],
#  ['AL'],
#  ['WI'],
#  ['KS'],
#  ['IN'],
#  ['OH'],
#  ['OH'],
#  ['OK'],
#  ['OK'],
#  ['NY'],
#  ['MI'],
#  ['WV'],
#  ['NC'],
#  ['PA'],
#  ['MS'],
#  ['NC'],
#  ['NE'],
#  ['IN'],
#  ['IL'],
#  ['LA'],
#  ['PA'],
#  ['WY'],
#  ['AZ'],
#  ['SC'],
#  ['WV'],
#  ['GA'],
#  ['ID'],
#  ['NC'],
#  ['AR'],
#  ['NM'],
#  ['KY'],
#  ['MS'],
#  ['IL'],
#  ['IN'],
#  ['AR'],
#  ['GA'],
#  ['SC'],
#  ['NY'],
#  ['KY'],
#  ['NC'],
#  ['WY'],
#  ['MI'],
#  ['TN'],
#  ['PA'],
#  ['IN'],
#  ['TN'],
#  ['WA'],
#  ['GA'],
#  ['NH'],
#  ['PA'],
#  ['KS'],
#  ['IA'],
#  ['AK'],
#  ['MT'],
#  ['MT'],
#  ['IL'],
#  ['IN'],
#  ['TN'],
#  ['IA', 'IL'],
#  ['IL'],
#  ['FL'],
#  ['AR'],
#  ['FL'],
#  ['OR'],
#  ['CA'],
#  ['WI', 'MI'],
#  ['IN'],
#  ['WI'],
#  ['IA'],
#  ['OH'],
#  ['NC'],
#  ['NC'],
#  ['MT'],
#  ['IN'],
#  ['NY'],
#  ['NY'],
#  ['GA'],
#  ['MI'],
#  ['NC'],
#  ['NY'],
#  ['OH'],
#  ['AL'],
#  ['NY'],
#  ['TN'],
#  ['AL'],
#  ['VT'],
#  ['MO'],
#  ['PA'],
#  ['NY'],
#  ['OH'],
#  ['NV'],
#  ['MN'],
#  ['CA'],
#  ['MD'],
#  ['MS'],
#  ['ID', 'WA'],
#  ['ND'],
#  ['PA'],
#  ['MN'],
#  ['OH'],
#  ['AR'],
#  ['VT'],
#  ['OK'],
#  ['MI'],
#  ['MS'],
#  ['NE'],
#  ['AZ'],
#  ['IA', 'IL', 'MO'],
#  ['OK'],
#  ['OR'],
#  ['FL'],
#  ['MS'],
#  ['KS'],
#  ['GA'],
#  ['TN'],
#  ['NM'],
#  ['MN'],
#  ['OR', 'ID'],
#  ['GA'],
#  ['PA'],
#  ['IN'],
#  ['IN'],
#  ['TX'],
#  ['IA'],
#  ['AL'],
#  ['OH'],
#  ['OH'],
#  ['NE'],
#  ['TN'],
#  ['PA'],
#  ['OH'],
#  ['MI'],
#  ['IL'],
#  ['NE'],
#  ['OH'],
#  ['OK'],
#  ['PA'],
#  ['NC'],
#  ['GA'],
#  ['NC'],
#  ['NC'],
#  ['NY'],
#  ['HI'],
#  ['MN'],
#  ['SD'],
#  ['IL'],
#  ['TX'],
#  ['AL'],
#  ['IA'],
#  ['GA'],
#  ['LA'],
#  ['IA'],
#  ['KY'],
#  ['AZ'],
#  ['TX'],
#  ['SC'],
#  ['WA'],
#  ['MT'],
#  ['FL'],
#  ['OK'],
#  ['TX'],
#  ['ID'],
#  ['MO'],
#  ['IN'],
#  ['KS'],
#  ['NM'],
#  ['CO'],
#  ['NC'],
#  ['OR'],
#  ['KS'],
#  ['KY'],
#  ['NV'],
#  ['OH'],
#  ['TN'],
#  ['ID'],
#  ['MO'],
#  ['OR'],
#  ['TN'],
#  ['MS'],
#  ['MI'],
#  ['MS'],
#  ['IA'],
#  ['AR'],
#  ['WA'],
#  ['IN'],
#  ['NY'],
#  ['KY'],
#  ['VT'],
#  ['TX'],
#  ['MN'],
#  ['IN'],
#  ['NY'],
#  ['IL'],
#  ['WA'],
#  ['AL'],
#  ['MI'],
#  ['MS'],
#  ['OH'],
#  ['NC'],
#  ['NC'],
#  ['OH'],
#  ['MN'],
#  ['MN'],
#  ['PA'],
#  ['WY'],
#  ['AR'],
#  ['IN'],
#  ['GA'],
#  ['NM'],
#  ['GA'],
#  ['IL'],
#  ['SD'],
#  ['SD'],
#  ['KY'],
#  ['KS'],
#  ['MN'],
#  ['OH'],
#  ['TN'],
#  ['WV', 'OH'],
#  ['MD'],
#  ['MO'],
#  ['IN'],
#  ['ID'],
#  ['OH'],
#  ['SC'],
#  ['MO'],
#  ['AL'],
#  ['AR'],
#  ['TN'],
#  ['KY'],
#  ['MN'],
#  ['FL'],
#  ['MS', 'LA'],
#  ['PA'],
#  ['TN'],
#  ['KY'],
#  ['NM'],
#  ['TX'],
#  ['MS'],
#  ['MD'],
#  ['IA'],
#  ['NE'],
#  ['MO'],
#  ['IN'],
#  ['OK'],
#  ['AL'],
#  ['WV'],
#  ['MI', 'WI'],
#  ['WI'],
#  ['OK'],
#  ['GA'],
#  ['VA'],
#  ['IN'],
#  ['OK'],
#  ['TX'],
#  ['MS'],
#  ['FL'],
#  ['NE'],
#  ['MN'],
#  ['MO'],
#  ['TX'],
#  ['IL'],
#  ['OH'],
#  ['MN'],
#  ['OH'],
#  ['CO'],
#  ['TX'],
#  ['GA'],
#  ['SC'],
#  ['MN'],
#  ['TX'],
#  ['TX'],
#  ['GA'],
#  ['LA'],
#  ['LA'],
#  ['KS'],
#  ['MI'],
#  ['GA'],
#  ['KY'],
#  ['KS'],
#  ['NV'],
#  ['PA'],
#  ['NV'],
#  ['AR'],
#  ['NM'],
#  ['MS'],
#  ['IA'],
#  ['TX'],
#  ['AR'],
#  ['GA'],
#  ['MI'],
#  ['MN'],
#  ['KS'],
#  ['LA'],
#  ['TN'],
#  ['NC'],
#  ['SD'],
#  ['PA'],
#  ['MO'],
#  ['NC'],
#  ['OH'],
#  ['WA'],
#  ['SD'],
#  ['NM'],
#  ['MN'],
#  ['TX'],
#  ['OH'],
#  ['IL'],
#  ['SC'],
#  ['MS'],
#  ['IN'],
#  ['GA'],
#  ['WY'],
#  ['IA'],
#  ['AL', 'GA'],
#  ['IN'],
#  ['LA'],
#  ['MN'],
#  ['WV'],
#  ['OR'],
#  ['MI'],
#  ['OK'],
#  ['OK'],
#  ['IN'],
#  ['WA'],
#  ['TX'],
#  ['MI'],
#  ['TX'],
#  ['NE'],
#  ['OK'],
#  ['KY'],
#  ['CO'],
#  ['MO'],
#  ['ID'],
#  ['GA'],
#  ['CO'],
#  ['AZ'],
#  ['IN'],
#  ['OR'],
#  ['TX'],
#  ['GA'],
#  ['NH'],
#  ['KY'],
#  ['MO'],
#  ['CA'],
#  ['NY'],
#  ['KS'],
#  ['KY'],
#  ['MI'],
#  ['CA'],
#  ['WV'],
#  ['OH'],
#  ['IN'],
#  ['WI'],
#  ['IL'],
#  ['UT'],
#  ['IN'],
#  ['UT'],
#  ['NE'],
#  ['WY', 'ID'],
#  ['TX'],
#  ['CO'],
#  ['MO'],
#  ['GA'],
#  ['AL'],
#  ['WA'],
#  ['AR'],
#  ['GA'],
#  ['WA'],
#  ['MT'],
#  ['MS'],
#  ['FL'],
#  ['TX'],
#  ['TN'],
#  ['MO'],
#  ['TX'],
#  ['LA'],
#  ['IL'],
#  ['TX'],
#  ['KY'],
#  ['AL'],
#  ['ND', 'MN'],
#  ['MS'],
#  ['AR'],
#  ['GA'],
#  ['OK'],
#  ['PA'],
#  ['TX'],
#  ['NM'],
#  ['NE'],
#  ['MO'],
#  ['OK'],
#  ['MI'],
#  ['OR'],
#  ['NC'],
#  ['MS'],
#  ['AR'],
#  ['MO'],
#  ['MN'],
#  ['OK'],
#  ['MI'],
#  ['WA'],
#  ['IA'],
#  ['KS'],
#  ['KS'],
#  ['OK'],
#  ['AR'],
#  ['KS'],
#  ['NY'],
#  ['AK'],
#  ['IA'],
#  ['WY'],
#  ['UT'],
#  ['TX'],
#  ['KS'],
#  ['UT'],
#  ['TX'],
#  ['MO'],
#  ['MN'],
#  ['NV'],
#  ['TX'],
#  ['IA'],
#  ['MO'],
#  ['LA'],
#  ['CO'],
#  ['WY'],
#  ['TN'],
#  ['OR'],
#  ['FL'],
#  ['ND'],
#  ['FL'],
#  ['FL'],
#  ['TX'],
#  ['SD'],
#  ['IL'],
#  ['IA'],
#  ['WY'],
#  ['AK'],
#  ['TX'],
#  ['CO'],
#  ['TX'],
#  ['OR'],
#  ['ID'],
#  ['ND'],
#  ['MO'],
#  ['NM'],
#  ['AR'],
#  ['ND'],
#  ['CA'],
#  ['SD'],
#  ['ID'],
#  ['LA'],
#  ['OK'],
#  ['NM'],
#  ['TX'],
#  ['OK'],
#  ['SD'],
#  ['ID'],
#  ['CO'],
#  ['KS'],
#  ['NM'],
#  ['NM'],
#  ['MA'],
#  ['NV'],
#  ['TX'],
#  ['AZ'],
#  ['OR'],
#  ['TX'],
#  ['TX'],
#  ['TX'],
#  ['CA'],
#  ['TX'],
#  ['TX'],
#  ['WY'],
#  ['TX'],
#  ['NM'],
#  ['NV'],
#  ['NM'],
#  ['NM'],
#  ['CO'],
#  ['TX'],
#  ['SD'],
#  ['OR'],
#  ['TX'],
#  ['TX'],
#  ['TX'],
#  ['TX'],
#  ['NM'],
#  ['TX'],
#  ['CO'],
#  ['TX'],
#  ['TX'],
#  ['TX'],
#  ['TX']]

# %%
ml = len(MSA_state_list)

# %%
cl = len(city_list)

# %%
a = [[]]*cl
b = [[]]*cl

for i in np.arange(cl):
    for j in np.arange(ml):
        if city_list[i] in MSA_city_list[j] and state_list[i] in MSA_state_list[j]:
            a[i] = MSA_name[j]
            b[i] = MSA[j]
        elif city_list[i]=='Boise' and state_list[i]=='ID':
            a[i] = 'Boise City, ID'
            b[i] = 14260
        elif city_list[i]=='Honolulu' and state_list[i]=='HI':
            a[i] = 'Urban Honolulu, HI'
            b[i] = 46520
        elif city_list[i]=='Lake Havasu' and state_list[i]=='AZ':
            a[i] = 'Lake Havasu City-Kingman, AZ'
            b[i] = 29420
        elif city_list[i]=='Lake Havasu' and state_list[i]=='AZ':
            a[i] = 'Lake Havasu City-Kingman, AZ'
            b[i] = 29420
        elif city_list[i]=='Long Island' and state_list[i]=='NY':
            a[i] = 'New York-Newwark-Jersey City, NY-NJ-PA'
            b[i] = 35620
        elif city_list[i]=='Louisville' and state_list[i]=='KY':
            a[i] = 'Louisville/Jefferson County, KY-IN'
            b[i] = 31140
        elif city_list[i]=='Northern Jersey City' and state_list[i]=='NJ':
            a[i] = 'New York-Newwark-Jersey City, NY-NJ-PA'
            b[i] = 35620
        elif city_list[i]=='Palm Spring' and state_list[i]=='FL':
            a[i] = 'Miami_Fort Lauderdale-Pompano, FL'
            b[i] = 33100
        elif city_list[i]=='Saint Louis' and state_list[i]=='MO':
            a[i] = 'St. Louis, MO-IL'
            b[i] = 41180

# %%
cre_stats["MSA Name"]= a
cre_stats["MSA"]= b

# %%
new_cres_stats = cre_stats[["MSA", "MSA Name", 'Property Class Name', 'Period', 'Slice', 'As Of', 'Geography Name',
                           'Property Type', 'Geography Code','Forecast Scenario', 'CBSA Code','Geography Type',
                           'Stock', 'Vacancy','Occupancy','Asking Rent','Asking Rent Index',
                           'Rent Growth','Rent Growth 12 Month','Demand','Net Absorption','Net Absorption 12 Months',
                           'Net Completions 12 Months','Cap Rate','Total Return',
 'Appreciation Return',
 'Income Return',
 'NOI Index',
 'Capital Value Index',
 'Price Index',
 'Price Growth',
 'Market Capitalization',
 'Office Employment',
 'Population',
 'Median Household Income',
 'Total Employment ',
 'Households',
 'Industrial Employment',
 'Transaction Cap Rate',
 '# Transaction Cap Rate',
 'Transaction PricePerArea',
 'Total Sales Volume',
 '# Sales Volume',
 'Sold Building SF',]]

# %%
cre_stats

# %%
new_cres_stats.head()
# Out:
#      MSA     MSA Name Property Class Name   Period Slice    As Of  \
# 0  10180  Abilene, TX          Industrial  1981 Q4   All  2019 Q3
# 1  10180  Abilene, TX          Industrial  1982 Q1   All  2019 Q3
# 2  10180  Abilene, TX          Industrial  1982 Q2   All  2019 Q3
# 3  10180  Abilene, TX          Industrial  1982 Q3   All  2019 Q3
# 4  10180  Abilene, TX          Industrial  1982 Q4   All  2019 Q3
#
#   Geography Name Property Type Geography Code          Forecast Scenario  ...  \
# 0   Abilene - TX           IND         G41554  Oxford Economics Baseline  ...
# 1   Abilene - TX           IND         G41554  Oxford Economics Baseline  ...
# 2   Abilene - TX           IND         G41554  Oxford Economics Baseline  ...
# 3   Abilene - TX           IND         G41554  Oxford Economics Baseline  ...
# 4   Abilene - TX           IND         G41554  Oxford Economics Baseline  ...
#
#    Median Household Income Total Employment  Households Industrial Employment  \
# 0                      NaN               NaN        NaN                   NaN
# 1                      NaN               NaN     50,890                   NaN
# 2                      NaN               NaN     51,427                   NaN
# 3                      NaN               NaN     51,962                   NaN
# 4                      NaN               NaN     52,271                   NaN
#
#   Transaction Cap Rate # Transaction Cap Rate  Transaction PricePerArea  \
# 0                  NaN                    NaN                       NaN
# 1                  NaN                    NaN                       NaN
# 2                  NaN                    NaN                       NaN
# 3                  NaN                    NaN                       NaN
# 4                  NaN                    NaN                       NaN
#
#   Total Sales Volume # Sales Volume Sold Building SF
# 0                NaN            NaN              NaN
# 1                NaN            NaN              NaN
# 2                NaN            NaN              NaN
# 3                NaN            NaN              NaN
# 4                NaN            NaN              NaN
#
# [5 rows x 44 columns]

# %%
new_cres_stats.to_csv('new_cre_stats_data2.csv')

# %%
# take q1, q2, q3 data out
import re

new_cres_stats2 = new_cres_stats[new_cres_stats.Period.str[6] == '4']
new_cres_stats2.head()
# Out:
#       MSA     MSA Name Property Class Name   Period Slice    As Of  \
# 0   10180  Abilene, TX          Industrial  1981 Q4   All  2019 Q3
# 4   10180  Abilene, TX          Industrial  1982 Q4   All  2019 Q3
# 8   10180  Abilene, TX          Industrial  1983 Q4   All  2019 Q3
# 12  10180  Abilene, TX          Industrial  1984 Q4   All  2019 Q3
# 16  10180  Abilene, TX          Industrial  1985 Q4   All  2019 Q3
#
#    Geography Name Property Type Geography Code          Forecast Scenario  \
# 0    Abilene - TX           IND         G41554  Oxford Economics Baseline
# 4    Abilene - TX           IND         G41554  Oxford Economics Baseline
# 8    Abilene - TX           IND         G41554  Oxford Economics Baseline
# 12   Abilene - TX           IND         G41554  Oxford Economics Baseline
# 16   Abilene - TX           IND         G41554  Oxford Economics Baseline
#
#     ...  Median Household Income Total Employment  Households  \
# 0   ...                      NaN               NaN        NaN
# 4   ...                      NaN               NaN     52,271
# 8   ...                      NaN               NaN     53,348
# 12  ...                   28,626               NaN     53,918
# 16  ...                   30,105               NaN     54,444
#
#    Industrial Employment Transaction Cap Rate # Transaction Cap Rate  \
# 0                    NaN                  NaN                    NaN
# 4                    NaN                  NaN                    NaN
# 8                    NaN                  NaN                    NaN
# 12                   NaN                  NaN                    NaN
# 16                   NaN                  NaN                    NaN
#
#     Transaction PricePerArea Total Sales Volume # Sales Volume  \
# 0                        NaN                NaN            NaN
# 4                        NaN                NaN            NaN
# 8                        NaN                NaN            NaN
# 12                       NaN                NaN            NaN
# 16                       NaN                NaN            NaN
#
#    Sold Building SF
# 0               NaN
# 4               NaN
# 8               NaN
# 12              NaN
# 16              NaN
#
# [5 rows x 44 columns]

# %%
# take "United States of America" rows out, create a new dataframe new_cres_stats3
new_cres_stats3 = new_cres_stats2[new_cres_stats2['Geography Name'] != "United States of America"]
new_cres_stats3.to_csv('new_cre_stats_data3.csv')

# %%
# creat year column
year_q = new_cres_stats3['Period'].to_list()
year_list = []
for i in year_q:
    year_list.append(i.split(' ')[0])

# %%
# assiagn year list to the 'year column in new_cres_stats3'

new_cres_stats3['year'] = year_list

# %%
new_cres_stats3 = new_cres_stats3[['MSA',
 'MSA Name',
 'Property Class Name',
 'year','Period',
 'Slice', 'As Of',
 'Geography Name',
 'Property Type',
 'Geography Code',
 'Forecast Scenario',
 'CBSA Code',
 'Geography Type',
 'Stock',
 'Vacancy',
 'Occupancy',
 'Asking Rent',
 'Asking Rent Index',
 'Rent Growth',
 'Rent Growth 12 Month',
 'Demand',
 'Net Absorption',
 'Net Absorption 12 Months',
 'Net Completions 12 Months',
 'Cap Rate',
 'Total Return',
 'Appreciation Return',
 'Income Return',
 'NOI Index',
 'Capital Value Index',
 'Price Index',
 'Price Growth',
 'Market Capitalization',
 'Office Employment',
 'Population',
 'Median Household Income',
 'Total Employment ',
 'Households',
 'Industrial Employment',
 'Transaction Cap Rate',
 '# Transaction Cap Rate',
 'Transaction PricePerArea',
 'Total Sales Volume',
 '# Sales Volume',
 'Sold Building SF']]

# %%
new_cres_stats3.to_csv('new_cre_stats_data3.csv')

# %%
# drop the columns we don't need 
new_cres_stats4 = new_cres_stats3.drop(columns = ['Property Class Name', 'Slice' ])

# %%
new_cres_stats4.head()
# Out:
#       MSA     MSA Name  year   Period    As Of Geography Name Property Type  \
# 0   10180  Abilene, TX  1981  1981 Q4  2019 Q3   Abilene - TX           IND
# 4   10180  Abilene, TX  1982  1982 Q4  2019 Q3   Abilene - TX           IND
# 8   10180  Abilene, TX  1983  1983 Q4  2019 Q3   Abilene - TX           IND
# 12  10180  Abilene, TX  1984  1984 Q4  2019 Q3   Abilene - TX           IND
# 16  10180  Abilene, TX  1985  1985 Q4  2019 Q3   Abilene - TX           IND
#
#    Geography Code          Forecast Scenario  CBSA Code  ...  \
# 0          G41554  Oxford Economics Baseline    10180.0  ...
# 4          G41554  Oxford Economics Baseline    10180.0  ...
# 8          G41554  Oxford Economics Baseline    10180.0  ...
# 12         G41554  Oxford Economics Baseline    10180.0  ...
# 16         G41554  Oxford Economics Baseline    10180.0  ...
#
#    Median Household Income Total Employment  Households Industrial Employment  \
# 0                      NaN               NaN        NaN                   NaN
# 4                      NaN               NaN     52,271                   NaN
# 8                      NaN               NaN     53,348                   NaN
# 12                  28,626               NaN     53,918                   NaN
# 16                  30,105               NaN     54,444                   NaN
#
#    Transaction Cap Rate  # Transaction Cap Rate Transaction PricePerArea  \
# 0                   NaN                     NaN                      NaN
# 4                   NaN                     NaN                      NaN
# 8                   NaN                     NaN                      NaN
# 12                  NaN                     NaN                      NaN
# 16                  NaN                     NaN                      NaN
#
#    Total Sales Volume # Sales Volume Sold Building SF
# 0                 NaN            NaN              NaN
# 4                 NaN            NaN              NaN
# 8                 NaN            NaN              NaN
# 12                NaN            NaN              NaN
# 16                NaN            NaN              NaN
#
# [5 rows x 43 columns]

# %%
file5 = "new_cre_stats_final_labor_columns.csv"

# %%
cre_stats_labor = pd.read_csv(file5)
cre_stats_labor.head()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (1,43,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ID    MSA     MSA Name Property Class Name   Period  Qtr      Yr  \
# 0   0  10180  Abilene, TX          Industrial  1981 Q4    4  1981.0
# 1   1  10180  Abilene, TX          Industrial  1982 Q1    1     NaN
# 2   2  10180  Abilene, TX          Industrial  1982 Q2    2     NaN
# 3   3  10180  Abilene, TX          Industrial  1982 Q3    3     NaN
# 4   4  10180  Abilene, TX          Industrial  1982 Q4    4  1982.0
#
#    Yr Lookup Slice    As Of  ... Location Quotient Age 45-54 % of Region  \
# 0        NaN   All  2019 Q3  ...               NaN                   NaN
# 1        NaN   All  2019 Q3  ...               NaN                   NaN
# 2        NaN   All  2019 Q3  ...               NaN                   NaN
# 3        NaN   All  2019 Q3  ...               NaN                   NaN
# 4        NaN   All  2019 Q3  ...               NaN                   NaN
#
#   Age 14-18 % of Region Age 19-21 % of Region  Age 22-24 % of Region  \
# 0                   NaN                   NaN                    NaN
# 1                   NaN                   NaN                    NaN
# 2                   NaN                   NaN                    NaN
# 3                   NaN                   NaN                    NaN
# 4                   NaN                   NaN                    NaN
#
#   Age 25-34 % of Region Age 35-44 % of Region Age 55-64 % of Region  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#   Age 65+ % of Region Unnamed: 59
# 0                 NaN         NaN
# 1                 NaN         NaN
# 2                 NaN         NaN
# 3                 NaN         NaN
# 4                 NaN         NaN
#
# [5 rows x 60 columns]

# %%
cre_stats_labor2 = cre_stats_labor[cre_stats_labor.Period.str[6] == '4']
cre_stats_labor2.head()
# Out:
#     ID    MSA     MSA Name Property Class Name   Period  Qtr      Yr  \
# 0    0  10180  Abilene, TX          Industrial  1981 Q4    4  1981.0
# 4    4  10180  Abilene, TX          Industrial  1982 Q4    4  1982.0
# 8    8  10180  Abilene, TX          Industrial  1983 Q4    4  1983.0
# 12  12  10180  Abilene, TX          Industrial  1984 Q4    4  1984.0
# 16  16  10180  Abilene, TX          Industrial  1985 Q4    4  1985.0
#
#     Yr Lookup Slice    As Of  ... Location Quotient Age 45-54 % of Region  \
# 0         NaN   All  2019 Q3  ...               NaN                   NaN
# 4         NaN   All  2019 Q3  ...               NaN                   NaN
# 8         NaN   All  2019 Q3  ...               NaN                   NaN
# 12        NaN   All  2019 Q3  ...               NaN                   NaN
# 16        NaN   All  2019 Q3  ...               NaN                   NaN
#
#    Age 14-18 % of Region Age 19-21 % of Region  Age 22-24 % of Region  \
# 0                    NaN                   NaN                    NaN
# 4                    NaN                   NaN                    NaN
# 8                    NaN                   NaN                    NaN
# 12                   NaN                   NaN                    NaN
# 16                   NaN                   NaN                    NaN
#
#    Age 25-34 % of Region Age 35-44 % of Region Age 55-64 % of Region  \
# 0                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 16                   NaN                   NaN                   NaN
#
#    Age 65+ % of Region Unnamed: 59
# 0                  NaN         NaN
# 4                  NaN         NaN
# 8                  NaN         NaN
# 12                 NaN         NaN
# 16                 NaN         NaN
#
# [5 rows x 60 columns]

# %%
# creat year column
year_q = cre_stats_labor2['Period'].to_list()
year_list = []
for i in year_q:
    year_list.append(i.split(' ')[0])

# %%
cre_stats_labor2['year'] = year_list
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# take "United States of America" rows out, create a new dataframe new_cres_stats3
cre_stats_labor2 = cre_stats_labor2[cre_stats_labor2['Geography Name'] != "United States of America"]
cre_stats_labor2.to_csv('cre_stats_labor2.csv')

# %%
list(cre_stats_labor2.columns)
# Out:
# ['ID',
#  'MSA',
#  'MSA Name',
#  'Property Class Name',
#  'Period',
#  'Qtr',
#  'Yr',
#  'Yr Lookup',
#  'Slice',
#  'As Of',
#  'Geography Name',
#  'Property Type',
#  'Geography Code',
#  'Forecast Scenario',
#  'CBSA Code',
#  'Geography Type',
#  'Stock',
#  'Vacancy',
#  'Occupancy',
#  'Asking Rent',
#  'Asking Rent Index',
#  'Rent Growth',
#  'Rent Growth 12 Month',
#  'Demand',
#  'Net Absorption',
#  'Net Absorption 12 Months',
#  'Net Completions 12 Months',
#  'Cap Rate',
#  'Total Return',
#  'Appreciation Return',
#  'Income Return',
#  'NOI Index',
#  'Capital Value Index',
#  'Price Index',
#  'Price Growth',
#  'Market Capitalization',
#  'Office Employment',
#  'Population',
#  'Median Household Income',
#  'Total Employment ',
#  'Households',
#  'Industrial Employment',
#  'Transaction Cap Rate',
#  '# Transaction Cap Rate',
#  'Transaction PricePerArea',
#  'Total Sales Volume',
#  '# Sales Volume',
#  'Sold Building SF',
#  'Job',
#  'Resident Workers',
#  'Location Quotient',
#  'Age 45-54 % of Region',
#  'Age 14-18 % of Region',
#  'Age 19-21 % of Region',
#  'Age 22-24 % of Region',
#  'Age 25-34 % of Region',
#  'Age 35-44 % of Region',
#  'Age 55-64 % of Region',
#  'Age 65+ % of Region',
#  'Unnamed: 59',
#  'year']

# %%
cre_stats_labor2 = cre_stats_labor2[['ID',
 'MSA',
 'MSA Name',
 'Property Class Name',
'year','Period',
 'Qtr',
 'Yr',
 'Yr Lookup',
 'Slice',
 'As Of',
 'Geography Name',
 'Property Type',
 'Geography Code',
 'Forecast Scenario',
 'CBSA Code',
 'Geography Type',
 'Stock',
 'Vacancy',
 'Occupancy',
 'Asking Rent',
 'Asking Rent Index',
 'Rent Growth',
 'Rent Growth 12 Month',
 'Demand',
 'Net Absorption',
 'Net Absorption 12 Months',
 'Net Completions 12 Months',
 'Cap Rate',
 'Total Return',
 'Appreciation Return',
 'Income Return',
 'NOI Index',
 'Capital Value Index',
 'Price Index',
 'Price Growth',
 'Market Capitalization',
 'Office Employment',
 'Population',
 'Median Household Income',
 'Total Employment ',
 'Households',
 'Industrial Employment',
 'Transaction Cap Rate',
 '# Transaction Cap Rate',
 'Transaction PricePerArea',
 'Total Sales Volume',
 '# Sales Volume',
 'Sold Building SF',
 'Job',
 'Resident Workers',
 'Location Quotient',
 'Age 45-54 % of Region',
 'Age 14-18 % of Region',
 'Age 19-21 % of Region',
 'Age 22-24 % of Region',
 'Age 25-34 % of Region',
 'Age 35-44 % of Region',
 'Age 55-64 % of Region',
 'Age 65+ % of Region',
 'Unnamed: 59']]

# %%
cre_stats_labor2.to_csv('cre_stats_labor2.csv')

# %%
cre_stats_labor2 = pd.read_csv('cre_stats_labor2.csv')

# %%
cre_stats_labor3 = cre_stats_labor2.drop(['ID', 'Yr Lookup', 'Slice', 'Unnamed: 59'], axis = 1)

# %%
cre_stats_labor3.reset_index()
# Out:
#        index  Unnamed: 0    MSA     MSA Name Property Class Name  year  \
# 0          0           0  10180  Abilene, TX          Industrial  1981
# 1          1           4  10180  Abilene, TX          Industrial  1982
# 2          2           8  10180  Abilene, TX          Industrial  1983
# 3          3          12  10180  Abilene, TX          Industrial  1984
# 4          4          16  10180  Abilene, TX          Industrial  1985
# 5          5          20  10180  Abilene, TX          Industrial  1986
# 6          6          24  10180  Abilene, TX          Industrial  1987
# 7          7          28  10180  Abilene, TX          Industrial  1988
# 8          8          32  10180  Abilene, TX          Industrial  1989
# 9          9          36  10180  Abilene, TX          Industrial  1990
# 10        10          40  10180  Abilene, TX          Industrial  1991
# 11        11          44  10180  Abilene, TX          Industrial  1992
# 12        12          48  10180  Abilene, TX          Industrial  1993
# 13        13          52  10180  Abilene, TX          Industrial  1994
# 14        14          56  10180  Abilene, TX          Industrial  1995
# 15        15          60  10180  Abilene, TX          Industrial  1996
# 16        16          64  10180  Abilene, TX          Industrial  1997
# 17        17          68  10180  Abilene, TX          Industrial  1998
# 18        18          72  10180  Abilene, TX          Industrial  1999
# 19        19          76  10180  Abilene, TX          Industrial  2000
# 20        20          80  10180  Abilene, TX          Industrial  2001
# 21        21          84  10180  Abilene, TX          Industrial  2002
# 22        22          88  10180  Abilene, TX          Industrial  2003
# 23        23          92  10180  Abilene, TX          Industrial  2004
# 24        24          96  10180  Abilene, TX          Industrial  2005
# 25        25         100  10180  Abilene, TX          Industrial  2006
# 26        26         104  10180  Abilene, TX          Industrial  2007
# 27        27         108  10180  Abilene, TX          Industrial  2008
# 28        28         112  10180  Abilene, TX          Industrial  2009
# 29        29         116  10180  Abilene, TX          Industrial  2010
# ...      ...         ...    ...          ...                 ...   ...
# 16348  16348       64785  49740     Yuma, AZ          Industrial  1993
# 16349  16349       64789  49740     Yuma, AZ          Industrial  1994
# 16350  16350       64793  49740     Yuma, AZ          Industrial  1995
# 16351  16351       64797  49740     Yuma, AZ          Industrial  1996
# 16352  16352       64801  49740     Yuma, AZ          Industrial  1997
# 16353  16353       64805  49740     Yuma, AZ          Industrial  1998
# 16354  16354       64809  49740     Yuma, AZ          Industrial  1999
# 16355  16355       64813  49740     Yuma, AZ          Industrial  2000
# 16356  16356       64817  49740     Yuma, AZ          Industrial  2001
# 16357  16357       64821  49740     Yuma, AZ          Industrial  2002
# 16358  16358       64825  49740     Yuma, AZ          Industrial  2003
# 16359  16359       64829  49740     Yuma, AZ          Industrial  2004
# 16360  16360       64833  49740     Yuma, AZ          Industrial  2005
# 16361  16361       64837  49740     Yuma, AZ          Industrial  2006
# 16362  16362       64841  49740     Yuma, AZ          Industrial  2007
# 16363  16363       64845  49740     Yuma, AZ          Industrial  2008
# 16364  16364       64849  49740     Yuma, AZ          Industrial  2009
# 16365  16365       64853  49740     Yuma, AZ          Industrial  2010
# 16366  16366       64857  49740     Yuma, AZ          Industrial  2011
# 16367  16367       64861  49740     Yuma, AZ          Industrial  2012
# 16368  16368       64865  49740     Yuma, AZ          Industrial  2013
# 16369  16369       64869  49740     Yuma, AZ          Industrial  2014
# 16370  16370       64873  49740     Yuma, AZ          Industrial  2015
# 16371  16371       64877  49740     Yuma, AZ          Industrial  2016
# 16372  16372       64881  49740     Yuma, AZ          Industrial  2017
# 16373  16373       64885  49740     Yuma, AZ          Industrial  2018
# 16374  16374       64889  49740     Yuma, AZ          Industrial  2019
# 16375  16375       64893  49740     Yuma, AZ          Industrial  2020
# 16376  16376       64897  49740     Yuma, AZ          Industrial  2021
# 16377  16377       64901  49740     Yuma, AZ          Industrial  2022
#
#         Period  Qtr    Yr    As Of  ... Resident Workers Location Quotient  \
# 0      1981 Q4    4  1981  2019 Q3  ...              NaN               NaN
# 1      1982 Q4    4  1982  2019 Q3  ...              NaN               NaN
# 2      1983 Q4    4  1983  2019 Q3  ...              NaN               NaN
# 3      1984 Q4    4  1984  2019 Q3  ...              NaN               NaN
# 4      1985 Q4    4  1985  2019 Q3  ...              NaN               NaN
# 5      1986 Q4    4  1986  2019 Q3  ...              NaN               NaN
# 6      1987 Q4    4  1987  2019 Q3  ...              NaN               NaN
# 7      1988 Q4    4  1988  2019 Q3  ...              NaN               NaN
# 8      1989 Q4    4  1989  2019 Q3  ...              NaN               NaN
# 9      1990 Q4    4  1990  2019 Q3  ...              NaN               NaN
# 10     1991 Q4    4  1991  2019 Q3  ...              NaN               NaN
# 11     1992 Q4    4  1992  2019 Q3  ...              NaN               NaN
# 12     1993 Q4    4  1993  2019 Q3  ...              NaN               NaN
# 13     1994 Q4    4  1994  2019 Q3  ...              NaN               NaN
# 14     1995 Q4    4  1995  2019 Q3  ...              NaN               NaN
# 15     1996 Q4    4  1996  2019 Q3  ...              NaN               NaN
# 16     1997 Q4    4  1997  2019 Q3  ...              NaN               NaN
# 17     1998 Q4    4  1998  2019 Q3  ...              NaN               NaN
# 18     1999 Q4    4  1999  2019 Q3  ...              NaN               NaN
# 19     2000 Q4    4  2000  2019 Q3  ...              NaN               NaN
# 20     2001 Q4    4  2001  2019 Q3  ...      2032.333371          0.639307
# 21     2002 Q4    4  2002  2019 Q3  ...      2002.977813          0.641743
# 22     2003 Q4    4  2003  2019 Q3  ...      1983.574047          0.647971
# 23     2004 Q4    4  2004  2019 Q3  ...      2061.346564          0.651612
# 24     2005 Q4    4  2005  2019 Q3  ...      2077.471380          0.642872
# 25     2006 Q4    4  2006  2019 Q3  ...      2196.528996          0.655416
# 26     2007 Q4    4  2007  2019 Q3  ...      2235.176336          0.658547
# 27     2008 Q4    4  2008  2019 Q3  ...      2344.488870          0.672217
# 28     2009 Q4    4  2009  2019 Q3  ...      2230.021576          0.675741
# 29     2010 Q4    4  2010  2019 Q3  ...      2218.500151          0.665748
# ...        ...  ...   ...      ...  ...              ...               ...
# 16348  1993 Q4    4  1993  2019 Q3  ...              NaN               NaN
# 16349  1994 Q4    4  1994  2019 Q3  ...              NaN               NaN
# 16350  1995 Q4    4  1995  2019 Q3  ...              NaN               NaN
# 16351  1996 Q4    4  1996  2019 Q3  ...              NaN               NaN
# 16352  1997 Q4    4  1997  2019 Q3  ...              NaN               NaN
# 16353  1998 Q4    4  1998  2019 Q3  ...              NaN               NaN
# 16354  1999 Q4    4  1999  2019 Q3  ...              NaN               NaN
# 16355  2000 Q4    4  2000  2019 Q3  ...              NaN               NaN
# 16356  2001 Q4    4  2001  2019 Q3  ...      2031.984636          0.867726
# 16357  2002 Q4    4  2002  2019 Q3  ...      2071.983648          0.875193
# 16358  2003 Q4    4  2003  2019 Q3  ...      2115.792804          0.880599
# 16359  2004 Q4    4  2004  2019 Q3  ...      2174.268257          0.848144
# 16360  2005 Q4    4  2005  2019 Q3  ...      2185.059482          0.842113
# 16361  2006 Q4    4  2006  2019 Q3  ...      2222.308970          0.814417
# 16362  2007 Q4    4  2007  2019 Q3  ...      2140.685345          0.805602
# 16363  2008 Q4    4  2008  2019 Q3  ...      2218.545924          0.837346
# 16364  2009 Q4    4  2009  2019 Q3  ...      2319.949820          0.832534
# 16365  2010 Q4    4  2010  2019 Q3  ...      2138.205490          0.790666
# 16366  2011 Q4    4  2011  2019 Q3  ...      2075.922252          0.749785
# 16367  2012 Q4    4  2012  2019 Q3  ...      2041.480461          0.718254
# 16368  2013 Q4    4  2013  2019 Q3  ...      2004.113553          0.702392
# 16369  2014 Q4    4  2014  2019 Q3  ...      2059.612126          0.685275
# 16370  2015 Q4    4  2015  2019 Q3  ...      2126.095484          0.687589
# 16371  2016 Q4    4  2016  2019 Q3  ...      2183.748239          0.685267
# 16372  2017 Q4    4  2017  2019 Q3  ...      2204.748071          0.676947
# 16373  2018 Q4    4  2018  2019 Q3  ...      2234.896974          0.667077
# 16374  2019 Q4    4  2019  2019 Q3  ...              NaN          0.664177
# 16375  2020 Q4    4  2020  2019 Q3  ...              NaN          0.663876
# 16376  2021 Q4    4  2021  2019 Q3  ...              NaN          0.663916
# 16377  2022 Q4    4  2022  2019 Q3  ...              NaN          0.664081
#
#       Age 45-54 % of Region Age 14-18 % of Region  Age 19-21 % of Region  \
# 0                       NaN                   NaN                    NaN
# 1                       NaN                   NaN                    NaN
# 2                       NaN                   NaN                    NaN
# 3                       NaN                   NaN                    NaN
# 4                       NaN                   NaN                    NaN
# 5                       NaN                   NaN                    NaN
# 6                       NaN                   NaN                    NaN
# 7                       NaN                   NaN                    NaN
# 8                       NaN                   NaN                    NaN
# 9                       NaN                   NaN                    NaN
# 10                      NaN                   NaN                    NaN
# 11                      NaN                   NaN                    NaN
# 12                      NaN                   NaN                    NaN
# 13                      NaN                   NaN                    NaN
# 14                      NaN                   NaN                    NaN
# 15                      NaN                   NaN                    NaN
# 16                      NaN                   NaN                    NaN
# 17                      NaN                   NaN                    NaN
# 18                      NaN                   NaN                    NaN
# 19                      NaN                   NaN                    NaN
# 20                      NaN                   NaN                    NaN
# 21                      NaN                   NaN                    NaN
# 22                      NaN                   NaN                    NaN
# 23                      NaN                   NaN                    NaN
# 24                      NaN                   NaN                    NaN
# 25                      NaN                   NaN                    NaN
# 26                      NaN                   NaN                    NaN
# 27                      NaN                   NaN                    NaN
# 28                      NaN                   NaN                    NaN
# 29                      NaN                   NaN                    NaN
# ...                     ...                   ...                    ...
# 16348                   NaN                   NaN                    NaN
# 16349                   NaN                   NaN                    NaN
# 16350                   NaN                   NaN                    NaN
# 16351                   NaN                   NaN                    NaN
# 16352                   NaN                   NaN                    NaN
# 16353                   NaN                   NaN                    NaN
# 16354                   NaN                   NaN                    NaN
# 16355                   NaN                   NaN                    NaN
# 16356                   NaN                   NaN                    NaN
# 16357                   NaN                   NaN                    NaN
# 16358                   NaN                   NaN                    NaN
# 16359                   NaN                   NaN                    NaN
# 16360                   NaN                   NaN                    NaN
# 16361                   NaN                   NaN                    NaN
# 16362                   NaN                   NaN                    NaN
# 16363                   NaN                   NaN                    NaN
# 16364                   NaN                   NaN                    NaN
# 16365                   NaN                   NaN                    NaN
# 16366                   NaN                   NaN                    NaN
# 16367                   NaN                   NaN                    NaN
# 16368                   NaN                   NaN                    NaN
# 16369                   NaN                   NaN                    NaN
# 16370                   NaN                   NaN                    NaN
# 16371                   NaN                   NaN                    NaN
# 16372                   NaN                   NaN                    NaN
# 16373              0.205499              0.014954               0.077183
# 16374                   NaN                   NaN                    NaN
# 16375                   NaN                   NaN                    NaN
# 16376                   NaN                   NaN                    NaN
# 16377                   NaN                   NaN                    NaN
#
#       Age 22-24 % of Region Age 25-34 % of Region Age 35-44 % of Region  \
# 0                       NaN                   NaN                   NaN
# 1                       NaN                   NaN                   NaN
# 2                       NaN                   NaN                   NaN
# 3                       NaN                   NaN                   NaN
# 4                       NaN                   NaN                   NaN
# 5                       NaN                   NaN                   NaN
# 6                       NaN                   NaN                   NaN
# 7                       NaN                   NaN                   NaN
# 8                       NaN                   NaN                   NaN
# 9                       NaN                   NaN                   NaN
# 10                      NaN                   NaN                   NaN
# 11                      NaN                   NaN                   NaN
# 12                      NaN                   NaN                   NaN
# 13                      NaN                   NaN                   NaN
# 14                      NaN                   NaN                   NaN
# 15                      NaN                   NaN                   NaN
# 16                      NaN                   NaN                   NaN
# 17                      NaN                   NaN                   NaN
# 18                      NaN                   NaN                   NaN
# 19                      NaN                   NaN                   NaN
# 20                      NaN                   NaN                   NaN
# 21                      NaN                   NaN                   NaN
# 22                      NaN                   NaN                   NaN
# 23                      NaN                   NaN                   NaN
# 24                      NaN                   NaN                   NaN
# 25                      NaN                   NaN                   NaN
# 26                      NaN                   NaN                   NaN
# 27                      NaN                   NaN                   NaN
# 28                      NaN                   NaN                   NaN
# 29                      NaN                   NaN                   NaN
# ...                     ...                   ...                   ...
# 16348                   NaN                   NaN                   NaN
# 16349                   NaN                   NaN                   NaN
# 16350                   NaN                   NaN                   NaN
# 16351                   NaN                   NaN                   NaN
# 16352                   NaN                   NaN                   NaN
# 16353                   NaN                   NaN                   NaN
# 16354                   NaN                   NaN                   NaN
# 16355                   NaN                   NaN                   NaN
# 16356                   NaN                   NaN                   NaN
# 16357                   NaN                   NaN                   NaN
# 16358                   NaN                   NaN                   NaN
# 16359                   NaN                   NaN                   NaN
# 16360                   NaN                   NaN                   NaN
# 16361                   NaN                   NaN                   NaN
# 16362                   NaN                   NaN                   NaN
# 16363                   NaN                   NaN                   NaN
# 16364                   NaN                   NaN                   NaN
# 16365                   NaN                   NaN                   NaN
# 16366                   NaN                   NaN                   NaN
# 16367                   NaN                   NaN                   NaN
# 16368                   NaN                   NaN                   NaN
# 16369                   NaN                   NaN                   NaN
# 16370                   NaN                   NaN                   NaN
# 16371                   NaN                   NaN                   NaN
# 16372                   NaN                   NaN                   NaN
# 16373              0.082489               0.23589              0.196334
# 16374                   NaN                   NaN                   NaN
# 16375                   NaN                   NaN                   NaN
# 16376                   NaN                   NaN                   NaN
# 16377                   NaN                   NaN                   NaN
#
#       Age 55-64 % of Region Age 65+ % of Region
# 0                       NaN                 NaN
# 1                       NaN                 NaN
# 2                       NaN                 NaN
# 3                       NaN                 NaN
# 4                       NaN                 NaN
# 5                       NaN                 NaN
# 6                       NaN                 NaN
# 7                       NaN                 NaN
# 8                       NaN                 NaN
# 9                       NaN                 NaN
# 10                      NaN                 NaN
# 11                      NaN                 NaN
# 12                      NaN                 NaN
# 13                      NaN                 NaN
# 14                      NaN                 NaN
# 15                      NaN                 NaN
# 16                      NaN                 NaN
# 17                      NaN                 NaN
# 18                      NaN                 NaN
# 19                      NaN                 NaN
# 20                      NaN                 NaN
# 21                      NaN                 NaN
# 22                      NaN                 NaN
# 23                      NaN                 NaN
# 24                      NaN                 NaN
# 25                      NaN                 NaN
# 26                      NaN                 NaN
# 27                      NaN                 NaN
# 28                      NaN                 NaN
# 29                      NaN                 NaN
# ...                     ...                 ...
# 16348                   NaN                 NaN
# 16349                   NaN                 NaN
# 16350                   NaN                 NaN
# 16351                   NaN                 NaN
# 16352                   NaN                 NaN
# 16353                   NaN                 NaN
# 16354                   NaN                 NaN
# 16355                   NaN                 NaN
# 16356                   NaN                 NaN
# 16357                   NaN                 NaN
# 16358                   NaN                 NaN
# 16359                   NaN                 NaN
# 16360                   NaN                 NaN
# 16361                   NaN                 NaN
# 16362                   NaN                 NaN
# 16363                   NaN                 NaN
# 16364                   NaN                 NaN
# 16365                   NaN                 NaN
# 16366                   NaN                 NaN
# 16367                   NaN                 NaN
# 16368                   NaN                 NaN
# 16369                   NaN                 NaN
# 16370                   NaN                 NaN
# 16371                   NaN                 NaN
# 16372                   NaN                 NaN
# 16373              0.146647            0.041003
# 16374                   NaN                 NaN
# 16375                   NaN                 NaN
# 16376                   NaN                 NaN
# 16377                   NaN                 NaN
#
# [16378 rows x 59 columns]

# %%
cre_stats_labor3 = cre_stats_labor3.drop(columns = ['Unnamed: 0'])

# %%
cre_stats_labor3.to_csv('cre_stats_labor3.csv')
